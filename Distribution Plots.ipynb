# %%
import numpy as np;
import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy.stats import laplace

sigma2 = 1.0
#b = 1.0 / np.sqrt(2.0 * sigma2)
#b=1

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(xs, norm.pdf(xs), label='Normal');
ax.plot(xs, laplace.pdf(xs, 0, sigma2), label='Laplace sigma=1');
ax.plot(xs, laplace.pdf(xs, 0, 0.5), label='Laplace sigma=0.5');
#ax.plot(xs, laplace.pdf(xs, 0, 0.05), label='Laplace sigma=0.05');
ax.legend();
plt.show()

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(xs, norm.cdf(xs), label='Normal');
ax.plot(xs, laplace.cdf(xs, 0, sigma2), label='Laplace sigma=1');
ax.plot(xs, laplace.cdf(xs, 0, 0.5), label='Laplace sigma=0.5');
ax.plot(xs, laplace.cdf(xs, 0, 0.05), label='Laplace sigma=0.05');
ax.legend();
plt.show()
