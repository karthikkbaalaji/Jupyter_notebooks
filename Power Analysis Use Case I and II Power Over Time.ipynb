# %%
source_file_dir='/Users/abertran/Documents/gitRepositories/TTL_prod_code/'
source(paste(source_file_dir,"readBoxPlotCSVDataPower.R",sep=""))
source(paste(source_file_dir,"readBoxPlotCSVDataRolePower.R",sep=""))
options(repr.plot.width=6.5, repr.plot.height=4)
options(digits=2)
data_dir='/Users/abertran/Documents/Data/Power_data/'
file_name='power_box_plot_eu5.csv'
data_boxPlot=readBoxPlotCSVDataPower(data_dir,file_name)
file_name='power_box_plot_role_eu5.csv'
data_boxPlot_role=readBoxPlotCSVDataRolePower(data_dir,file_name)

# %%
models=unique(data_boxPlot$model)
interested_model=models[1]
data_boxPlot_model= data_boxPlot[which(data_boxPlot$model==interested_model),]
boxplot(t(data_boxPlot_model[,c("power_min","power_p25","power_p50","power_p75","power_max")]),names=data_boxPlot_model$week_key)
title(interested_model)
# Out:
# Plot with title “DL360 Gen9”

# %%
plot(data_boxPlot_model$week_key,data_boxPlot_model$power_p95,ty='l',ylim=c(min(data_boxPlot_model$power_p95),max(data_boxPlot_model$power_p99)),xlab="Week",ylab="Power quantile");
lines(data_boxPlot_model$week_key,data_boxPlot_model$power_p99,col='red')
grid()
# Out:
# plot without title

# %%
interested_model=models[2]
data_boxPlot_model= data_boxPlot[which(data_boxPlot$model==interested_model),]
boxplot(t(data_boxPlot_model[,c("power_min","power_p25","power_p50","power_p75","power_max")]),names=data_boxPlot_model$week_key)
title(interested_model)
plot(data_boxPlot_model$week_key,data_boxPlot_model$power_p95,ty='l',ylim=c(min(data_boxPlot_model$power_p95),max(data_boxPlot_model$power_p99)),xlab="Week",ylab="Power quantile");
lines(data_boxPlot_model$week_key,data_boxPlot_model$power_p99,col='red')
grid()
# Out:
# Plot with title “DL360P”
# plot without title

# %%
interested_model=models[3]
data_boxPlot_model= data_boxPlot[which(data_boxPlot$model==interested_model),]
boxplot(t(data_boxPlot_model[,c("power_min","power_p25","power_p50","power_p75","power_max")]),names=data_boxPlot_model$week_key)
title(interested_model)
plot(data_boxPlot_model$week_key,data_boxPlot_model$power_p95,ty='l',ylim=c(min(data_boxPlot_model$power_p95),max(data_boxPlot_model$power_p99)),xlab="Week",ylab="Power quantile");
lines(data_boxPlot_model$week_key,data_boxPlot_model$power_p99,col='red')
grid()
# Out:
# Plot with title “DL560”
# plot without title

# %%
interested_model=models[4]
data_boxPlot_model= data_boxPlot[which(data_boxPlot$model==interested_model),]
boxplot(t(data_boxPlot_model[,c("power_min","power_p25","power_p50","power_p75","power_max")]),names=data_boxPlot_model$week_key)
title(interested_model)
plot(data_boxPlot_model$week_key,data_boxPlot_model$power_p95,ty='l',ylim=c(min(data_boxPlot_model$power_p95),280),xlab="Week",ylab="Power quantile");
#max(data_boxPlot_model$power_p99)
lines(data_boxPlot_model$week_key,data_boxPlot_model$power_p99,col='red')
grid()
# Out:
# Plot with title “R430”
# plot without title

# %% [markdown]
# Let's look at Use Case #2 on a per role per model scenario

# %%
interested_model=models[1]
interested_role='app'
data_boxPlot_model= data_boxPlot_role[which(data_boxPlot_role$model==interested_model & data_boxPlot_role$role==interested_role),]
boxplot(t(data_boxPlot_model[,c("power_min","power_p25","power_p50","power_p75","power_max")]),names=data_boxPlot_model$week_key)
title(paste(interested_model,' ',interested_role,sep=""))
plot(data_boxPlot_model$week_key,data_boxPlot_model$power_p95,ty='l',ylim=c(min(data_boxPlot_model$power_p95),max(data_boxPlot_model$power_p99)),xlab="Week",ylab="Power quantile");
#max(data_boxPlot_model$power_p99)
lines(data_boxPlot_model$week_key,data_boxPlot_model$power_p99,col='red')
title(paste(interested_model,' ',interested_role,sep=""))
grid()
# Out:
# Plot with title “DL360 Gen9 app”
# Plot with title “DL360 Gen9 app”

# %%
interested_model=models[1]
interested_role='ffx'
data_boxPlot_model= data_boxPlot_role[which(data_boxPlot_role$model==interested_model & data_boxPlot_role$role==interested_role),]
boxplot(t(data_boxPlot_model[,c("power_min","power_p25","power_p50","power_p75","power_max")]),names=data_boxPlot_model$week_key)
title(paste(interested_model,' ',interested_role,sep=""))
plot(data_boxPlot_model$week_key,data_boxPlot_model$power_p95,ty='l',ylim=c(min(data_boxPlot_model$power_p95),max(data_boxPlot_model$power_p99)),xlab="Week",ylab="Power quantile");
#max(data_boxPlot_model$power_p99)
lines(data_boxPlot_model$week_key,data_boxPlot_model$power_p99,col='red')
title(paste(interested_model,' ',interested_role,sep=""))
grid()
# Out:
# Plot with title “DL360 Gen9 ffx”
# Plot with title “DL360 Gen9 ffx”

# %%
q=data_boxPlot_role[which(data_boxPlot_role$model==interested_model),]
unique(q$role)
# Out:
# [1] "monitor" "search"  "proxy"   "ffx"     "mq"      "hub"     "cbatch"
# [8] "dapp"    "app"

# %%
interested_model=models[1]
interested_role='search'
data_boxPlot_model= data_boxPlot_role[which(data_boxPlot_role$model==interested_model & data_boxPlot_role$role==interested_role),]
boxplot(t(data_boxPlot_model[,c("power_min","power_p25","power_p50","power_p75","power_max")]),names=data_boxPlot_model$week_key)
title(paste(interested_model,' ',interested_role,sep=""))
plot(data_boxPlot_model$week_key,data_boxPlot_model$power_p95,ty='l',ylim=c(min(data_boxPlot_model$power_p95),max(data_boxPlot_model$power_p99)),xlab="Week",ylab="Power quantile");
#max(data_boxPlot_model$power_p99)
lines(data_boxPlot_model$week_key,data_boxPlot_model$power_p99,col='red')
title(paste(interested_model,' ',interested_role,sep=""))
grid()
# Out:
# Plot with title “DL360 Gen9 search”
# Plot with title “DL360 Gen9 search”
